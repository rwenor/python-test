# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import MySQLdb as db

from pandas import DataFrame
from pandas.io.sql import frame_query

sett_nr = '415'
ax_nr = '3306'

# admdb = db.connect('dbserver.datk.vpn','DatkUtv','Bjo#Br1ds0!','datk')
admdb = db.connect('axspeed.datk.no','AXS_Serv','axs*sxa','Axs_db')

# %%
sql = "select plass from Axspeed "
data     = pd.read_sql(sql, admdb)# frame_query(sql, database)

m_kode = data.iloc[0]['plass']

print "Henter data fra "+ sett_nr +" for "+ m_kode
# Out:
# Henter data fra 415 for Kjerka

# %%
m_kode = '1440006'

database = db.connect('datk'+ sett_nr +'.datk.vpn','DatkLogger','ax','Datklog')
sql = "SELECT * FROM kjoretoylog where Tellepunkt  = "+ m_kode \
          +" order by KjoretoyId desc LIMIT 0,2000"
data     = pd.read_sql(sql, database )# frame_query(sql, database)

print "Data hentet"
# Out:
# Data hentet

# %%
data.head(20) #.Hastighet.mean()
# Out:
#     KjoretoyId  Tellepunkt                 Tid  Felt  Hastighet  Akselavstand  \
# 0       863411     1440006 2016-01-25 09:34:17     1       72.4          2.62
# 1       863410     1440006 2016-01-25 09:33:57     1       71.9          5.48
# 2       863409     1440006 2016-01-25 09:33:49     1       72.0          4.29
# 3       863408     1440006 2016-01-25 09:33:48     2        0.0          0.00
# 4       863405     1440006 2016-01-25 09:31:47     1       74.7          2.89
# 5       863402     1440006 2016-01-25 09:31:19     1       72.3          2.67
# 6       863401     1440006 2016-01-25 09:30:59     1       69.8          2.73
# 7       863400     1440006 2016-01-25 09:30:57     1       67.5          2.66
# 8       863399     1440006 2016-01-25 09:30:55     1       67.4          2.62
# 9       863398     1440006 2016-01-25 09:29:08     1       73.8          2.57
# 10      863391     1440006 2016-01-25 09:25:38     1       65.8          2.77
# 11      863390     1440006 2016-01-25 09:25:33     1       61.3          2.61
# 12      863385     1440006 2016-01-25 09:19:03     1       69.6          3.79
# 13      863368     1440006 2016-01-25 09:12:42     1       80.3          3.11
# 14      863366     1440006 2016-01-25 09:11:25     1       88.4          6.95
# 15      863363     1440006 2016-01-25 09:08:08     1       67.4          3.08
# 16      863362     1440006 2016-01-25 09:08:06     1       70.0          2.99
# 17      863359     1440006 2016-01-25 09:07:18     1       72.0          3.29
# 18      863356     1440006 2016-01-25 09:05:05     1       73.4          3.08
# 19      863355     1440006 2016-01-25 09:03:58     1       72.7          3.00
#
#       Vekt Kode  Status
# 0    1.172   SP       0
# 1   17.094   SP       0
# 2   14.176   SP       0
# 3    0.000   SN       1
# 4    1.526   SP       0
# 5    1.121   SP       0
# 6    1.173   SP       0
# 7    1.053   SP       0
# 8    1.083   SP       0
# 9    1.038   SP       0
# 10   1.095   SP       0
# 11   1.085   SP       0
# 12  21.636   SP       0
# 13   1.671   SP       0
# 14  11.020   SP       0
# 15   1.312   SP       0
# 16   1.426   SP       0
# 17   1.766   SP       0
# 18   1.174   SP       0
# 19   1.760   SP       0

# %%
data.tail()
# Out:
#       KjoretoyId  Tellepunkt                 Tid  Felt  Hastighet  \
# 1995      857983     1440006 2016-01-22 14:51:22     1       70.6
# 1996      857976     1440006 2016-01-22 14:49:02     1       88.2
# 1997      857969     1440006 2016-01-22 14:46:27     1       71.7
# 1998      857968     1440006 2016-01-22 14:46:17     1       71.0
# 1999      857967     1440006 2016-01-22 14:45:16     1       77.7
#
#       Akselavstand   Vekt Kode  Status
# 1995          2.72  1.397   SP       0
# 1996          3.01  1.541   SP       0
# 1997          2.77  1.470   SP       0
# 1998          2.55  1.329   SP       0
# 1999          2.97  0.615   SP       0

# %%
'''
d_st = data[data.Kode == 'ST']
d_sl = data[data.Kode == 'SL']
d_sp = data[data.Kode == 'SP']
d_sn = data[data.Kode == 'SN']
print d_st.count()/data.count()
print d_sl.count()/data.count()
print d_sp.count()/data.count()
print d_sn.count()/data.count()
'''
# Out:
# "\nd_st = data[data.Kode == 'ST']\nd_sl = data[data.Kode == 'SL']\nd_sp = data[data.Kode == 'SP']\nd_sn = data[data.Kode == 'SN']\nprint d_st.count()/data.count()\nprint d_sl.count()/data.count()\nprint d_sp.count()/data.count()\nprint d_sn.count()/data.count()\n"

# %%
data.groupby(['Kode']).count()
# Out:
#       KjoretoyId  Tellepunkt   Tid  Felt  Hastighet  Akselavstand  Vekt  \
# Kode
# SN           103         103   103   103        103           103   103
# SP          1897        1897  1897  1897       1897          1897  1897
#
#       Status
# Kode
# SN       103
# SP      1897

# %%
hist_H1 = data.Hastighet.hist(bins=100, range=(10,100))

# %%
hist_H2 = data[data.Felt==2].Hastighet.hist(bins=100, range=(10,100))
